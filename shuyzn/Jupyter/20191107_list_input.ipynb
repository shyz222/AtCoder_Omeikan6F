# %% [markdown]
# # listとinputについて

# %%
input()
# Out:
# python
# 'python'

# %%
input().split()
# Out:
# python
# ['python']

# %%
list(input())
# Out:
# python
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
a = input().split()
# Out:
# 1 2 3 4 5

# %%
a
# Out:
# ['1', '2', '3', '4', '5']

# %%
type(a[0])
# Out:
# str

# %%
# input()はデフォがstr型
# int型でかつリストに格納するには
b = list(map(int, input().split()))
# Out:
# 1 2 3 4 5

# %%
b
# Out:
# [1, 2, 3, 4, 5]

# %%
type(b[0])
# Out:
# int
